# %% [markdown]
#     Home Work 2  (Prob Stat)
#     จิรวัฒน์ แก้วกุลบุตร (60010143)

# %%
print("Hello Home Work 2 in (ProbStat)!")
# Out:
# Hello Home Work 2 in (ProbStat)!

# %%
import pandas as pd
import stemgraphic 
import numpy as np
import matplotlib.pyplot as plt

# %%
def estimate_gaussian(dataset):

    mu = np.mean(dataset)#moyenne cf mu
    sigma = np.std(dataset)#écart_type/standard deviation
    limit = sigma * 10.0
#     print(sigma)

    min_threshold = mu - limit
    max_threshold = mu + limit

    return mu, sigma, min_threshold, max_threshold

# %%
data = pd.read_csv("E:\Development\Prob Stat\Data\lovoo2015\lovoo_v3_users_api-results.csv")
print("row size and column size :",data.shape)
data.tail()
# Out:
# row size and column size : (3973, 42)
#      gender genderLooking  age    name  counts_details  counts_pictures  \
# 3968      F             M   21    B**f            0.85                1
# 3969      F             M   20   Ma**e            1.00                8
# 3970      F             M   20   Ma**e            1.00                8
# 3971      F             M   23  Eni**n            0.96                8
# 3972      F             M   23  Eni**n            0.96                9
#
#       counts_profileVisits  counts_kisses  counts_fans  counts_g  ...  \
# 3968                   280             15            0         0  ...
# 3969                  1014             43            3         0  ...
# 3970                  1101             46            3         0  ...
# 3971                  8702            142            0         0  ...
# 3972                  8904            143            0         0  ...
#
#       shareProfileEnabled        lastOnlineDate  lastOnlineTime birthd crypt  \
# 3968                    1  2015-04-07T00:08:59Z    1.428365e+09      0   1.0
# 3969                    1  2015-04-06T07:54:34Z    1.428307e+09      0   1.0
# 3970                    1  2015-04-06T07:54:34Z    1.428307e+09      0   1.0
# 3971                    0  2015-04-06T15:47:15Z    1.428335e+09      0   1.0
# 3972                    0  2015-04-19T08:38:08Z    1.429433e+09      0   1.0
#
#      freetext                                            whazzup  \
# 3968      NaN                                                NaN
# 3969      NaN  Marie ॐ                            🎉Goa.      ...
# 3970      NaN  Marie ॐ                            🎉Goa.      ...
# 3971      NaN                           ruhig shriebe😉. bissä ni
# 3972      NaN                           ruhig shriebe😉. bissä ni
#
#                                               pictureId  \
# 3968  CRYqKLbQ1+pd5CVSmGGccV+EggT4oGRmaXWhnn5jhMg9Jz...
# 3969  CRYq7MGpxHpEKfWhmwJygGmRNadHkC9XxPjktwvaiLm6Te...
# 3970  CRYVOrW7zgSV+NPGili4nZeREmQ0rAAXCZunTXp9KRLat1...
# 3971  CRYsH4q+r4fCkC8+leJqDdJQtbUNQGCyqLx36aDsEzC5b9...
# 3972  CRYbrX0C8ToNrsDqLPf+kLsCSuDY0TOhyKSo3Phw98sbl+...
#
#                                 userId  isSystemProfile
# 3968  cb958a9459216acd4dd06f213fe63685              NaN
# 3969  d5a7edbcb59fcb092871bdcde7f142ca              NaN
# 3970  d5a7edbcb59fcb092871bdcde7f142ca              NaN
# 3971  e532a6060fe4e5902c66086d905a9d53              NaN
# 3972  dc186f3855343c9f096c484f6d363aac              NaN
#
# [5 rows x 42 columns]

# %%
#เลือก Column เพื่อนำมาสร้าง DataFrame ใหม่ นำมาเฉพาะข้อมูลที่สนใจ
columns = list(data.columns)
print("size of column Data",len(columns))
index=0
for i in columns :
    print('id:',index,'name of column :',i)
    index+=1
    
useIdColumn = [0,1,2,3,5,6,7,8,9,10,11,12,13,15,17,18,19,23,24,32]
useColumn = []
for i in useIdColumn :
        useColumn.append(columns[i])
useColumn
# Out:
# size of column Data 42
# id: 0 name of column : gender
# id: 1 name of column : genderLooking
# id: 2 name of column : age
# id: 3 name of column : name
# id: 4 name of column : counts_details
# id: 5 name of column : counts_pictures
# id: 6 name of column : counts_profileVisits
# id: 7 name of column : counts_kisses
# id: 8 name of column : counts_fans
# id: 9 name of column : counts_g
# id: 10 name of column : flirtInterests_chat
# id: 11 name of column : flirtInterests_friends
# id: 12 name of column : flirtInterests_date
# id: 13 name of column : country
# id: 14 name of column : city
# id: 15 name of column : location
# id: 16 name of column : distance
# id: 17 name of column : isFlirtstar
# id: 18 name of column : isHighlighted
# id: 19 name of column : isInfluencer
# id: 20 name of column : isMobile
# id: 21 name of column : isNew
# id: 22 name of column : isOnline
# id: 23 name of column : isVip
# id: 24 name of column : lang_count
# id: 25 name of column : lang_fr
# id: 26 name of column : lang_en
# id: 27 name of column : lang_de
# id: 28 name of column : lang_it
# id: 29 name of column : lang_es
# id: 30 name of column : lang_pt
# id: 31 name of column : verified
# id: 32 name of column : shareProfileEnabled
# id: 33 name of column : lastOnlineDate
# id: 34 name of column : lastOnlineTime
# id: 35 name of column : birthd
# id: 36 name of column : crypt
# id: 37 name of column : freetext
# id: 38 name of column : whazzup
# id: 39 name of column : pictureId
# id: 40 name of column : userId
# id: 41 name of column : isSystemProfile
# ['gender',
#  'genderLooking',
#  'age',
#  'name',
#  'counts_pictures',
#  'counts_profileVisits',
#  'counts_kisses',
#  'counts_fans',
#  'counts_g',
#  'flirtInterests_chat',
#  'flirtInterests_friends',
#  'flirtInterests_date',
#  'country',
#  'location',
#  'isFlirtstar',
#  'isHighlighted',
#  'isInfluencer',
#  'isVip',
#  'lang_count',
#  'shareProfileEnabled']

# %%
dataFrame = data[useColumn]
dataFrame.head()
# Out:
#   gender genderLooking  age          name  counts_pictures  \
# 0      F             M   25         daeni                4
# 1      F             M   22   italiana 92                5
# 2      F             M   21       Lauraaa                4
# 3      F          none   20    Qqkwmdowlo                3
# 4      F             M   21  schaessie {3               12
#
#    counts_profileVisits  counts_kisses  counts_fans  counts_g  \
# 0                  8279            239            0         3
# 1                   663             13            0         0
# 2                  1369             88            0         2
# 3                 22187           1015            2         3
# 4                 35262           1413            9        12
#
#    flirtInterests_chat  flirtInterests_friends  flirtInterests_date country  \
# 0                 True                    True                 True      CH
# 1                 True                    True                 True      CH
# 2                False                   False                 True      CH
# 3                 True                    True                False      CA
# 4                 True                   False                False      DE
#
#   location  isFlirtstar  isHighlighted  isInfluencer  isVip  lang_count  \
# 0  Rümlang            0              0             0      0           1
# 1  Sissach            0              0             0      0           3
# 2     Bâle            0              0             0      0           0
# 3    Berne            0              0             0      0           2
# 4  Rastatt            0              0             0      0           1
#
#    shareProfileEnabled
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
gender = dataFrame.pivot_table(index=['gender'], aggfunc='size')
modeGender = max(list(gender))
print("เพศผู้ใช้งาน :",gender)
print("ค่าฐานนิยมเพศผู้ใช้งาน (Mode) :",modeGender)


genderLooking = dataFrame.pivot_table(index=['genderLooking'], aggfunc='size')
modeGenderLooking = max(list(genderLooking))
print("จำนวนความสนใจในเพศตรงข้ามของผู้หญิง  :",genderLooking)
print("ค่าฐานนิยมความสนใจในเพศตรงข้ามของผู้ญิง (Mode) :",modeGenderLooking)
# Out:
# เพศผู้ใช้งาน : gender
# F    3973
# dtype: int64
# ค่าฐานนิยมเพศผู้ใช้งาน (Mode) : 3973
# จำนวนความสนใจในเพศตรงข้ามของผู้หญิง  : genderLooking
# F         25
# M       3561
# both      21
# none     366
# dtype: int64
# ค่าฐานนิยมความสนใจในเพศตรงข้ามของผู้ญิง (Mode) : 3561

# %%
#max min mean ช่วงอายุของผู้ใช้งาน

maxAge = dataFrame['age'].max()
minAge = dataFrame['age'].min()
meanAge = dataFrame['age'].mean()
print("ช่วงอายุของผู้ใช้งาน (max = %d"%maxAge,"min = %d"%minAge,"min mean = %.6f)"%meanAge)

#max min mean ช่วงจำนวนของรูปภาพประจำผู้ใช้งาน

maxCountPicture = dataFrame['counts_pictures'].max()
minCountPicture = dataFrame['counts_pictures'].min()
meanCountPicture = dataFrame['counts_pictures'].mean()
print("ช่วงจำนวนของรูปภาพประจำผู้ใช้งาน (max = %d"%maxCountPicture,"min = %d"%minCountPicture,"min mean = %.6f)"%meanCountPicture)

#max min mean ช่วงจำนวนผู้เข้าชม my profile ของผู้ใช้งาน

maxProfileVisits= dataFrame['counts_profileVisits'].max()
minProfileVisits = dataFrame['counts_profileVisits'].min()
meanProfileVisits = dataFrame['counts_profileVisits'].mean()
print("ช่วงจำนวนผู้เข้าชม my profile ของผู้ใช้งาน (max = %d"%maxProfileVisits,"min = %d"%minProfileVisits,"min mean = %.6f)"%meanProfileVisits)
# Out:
# ช่วงอายุของผู้ใช้งาน (max = 28 min = 18 min mean = 21.995973)
# ช่วงจำนวนของรูปภาพประจำผู้ใช้งาน (max = 30 min = 0 min mean = 4.789831)
# ช่วงจำนวนผู้เข้าชม my profile ของผู้ใช้งาน (max = 164425 min = 0 min mean = 3710.107727)

# %%
dStd = dataFrame[['age','counts_profileVisits']]
dStd.std(axis = 0, skipna = True)
# Out:
# age                        1.961868
# counts_profileVisits    6857.418509
# dtype: float64

# %%
useIdColumn = [2,5,6,7,8,9,23,24,32]
useColumn = []
for i in useIdColumn :
        useColumn.append(columns[i])
print(useColumn)
dataFrame = data[useColumn]
dataFrame.head()
hist = dataFrame.hist(figsize = (15,20))
# Out:
# ['age', 'counts_pictures', 'counts_profileVisits', 'counts_kisses', 'counts_fans', 'counts_g', 'isVip', 'lang_count', 'shareProfileEnabled']

# %%
dataFrame = data[useColumn]
boxplot = dataFrame.boxplot(figsize = (15,20))

# %%
for i in range(0,2) :
    ListData = dataFrame[useColumn[i]].values.tolist()
    stemData = pd.Series(ListData)
    print ("Stem and Leaf with column :",useColumn[i])
    print(stemgraphic.stem_graphic(stemData))
# print(ageList)
# Out:
# Stem and Leaf with column : age
# (<Figure size 540x324 with 1 Axes>, <matplotlib.axes._axes.Axes object at 0x0000022D3676E760>)
# Stem and Leaf with column : counts_pictures
# (<Figure size 540x630 with 1 Axes>, <matplotlib.axes._axes.Axes object at 0x0000022D36C4A340>)

# %%
mu, sigma, min_threshold, max_threshold = estimate_gaussian(dataFrame['counts_profileVisits'].values)
condition1 = (dataFrame['counts_profileVisits'] < min_threshold)
condition2 = (dataFrame['counts_profileVisits'] > max_threshold)

outliers = np.extract(condition2, dataFrame['counts_profileVisits'])


df_red = dataFrame[dataFrame['counts_profileVisits'].values==outliers]
# print(df_red)
plt.scatter(dataFrame['counts_profileVisits'],dataFrame['age'])
plt.scatter(df_red['counts_profileVisits'],df_red['age'],c='red')
plt.ylabel("age")
plt.xlabel("counts_profileVisits")
plt.figure(figsize=(20,8))
plt.show()
